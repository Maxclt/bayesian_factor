# %%
import numpy as np

from src.simulations.normal_bayesian_factor_dgp import NormalBayesianFactorDGP

from src.utils.setup.create_true_loadings import create_true_loadings

# TODO modify this to have the possibility to set the parameter when running the file

# Force Random Seed
# np.random.seed(42)

# Normal Factor Bayesian Dimensions
num_sim = 100
num_variables = 1956
num_factors = 8

# True Loadings Settings
block_size = 500
overlap = 136
random = False
mean = 1
std = 5

# Hyperparameters
alpha = 1 / num_variables
eta = 1
epsilon = 1
lambda0 = 200  # try with lambda greater
lambda1 = 1


# True Parameters
BTrue = create_true_loadings(
    num_factors=num_factors,
    num_variables=num_variables,
    block_size=block_size,
    overlap=overlap,
    random=random,
    mean=mean,
    std=std,
)

SigmaTrue = np.ones(
    num_variables
)  # TODO define a function to create_true_covariance either random or not

# Initial Latent Parameters
Gamma0 = create_true_loadings(
    num_factors=num_factors,
    num_variables=num_variables,
    block_size=block_size,
    overlap=overlap,
)

Theta0 = np.full((num_factors,), 0.5)

# Simulated Value for Y
DataGeneratingProcess = NormalBayesianFactorDGP(B=BTrue, Sigma=SigmaTrue)

Y_sim = DataGeneratingProcess.simulate(size=num_sim)

# %%
from src.sampling.ghosh_dunson import GhoshDunsonGibbs
# Initiate Bayesian Normal Factor Gibbs Sampler
SparseGibbsSampling = GhoshDunsonGibbs(
    Y=Y_sim,
    B=BTrue,
    Sigma=SigmaTrue,
    Gamma=Gamma0,
    Theta=Theta0,
    alpha=alpha,
    eta=eta,
    epsilon=epsilon,
    lambda0=lambda0,
    lambda1=lambda1,
)

# Perform Gibbs Sampler for posterior
SparseGibbsSampling.perform_gibbs(iterations=100)
# Out:
# Gibbs Sampling:   1%|          | 1/100 [00:07<12:55,  7.83s/iter]
# Check Theta: [0.27960611 0.2790984  0.27606481 0.26238165 0.25612182 0.00873969
#  0.00839102 0.00767901]
# Gibbs Sampling:   2%|▏         | 2/100 [00:10<08:14,  5.05s/iter]
# Check Theta: [0.73689737 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:   3%|▎         | 3/100 [00:14<06:52,  4.26s/iter]
# Check Theta: [0.2946488 0.        0.        0.        0.        0.        0.
#  0.       ]
# Gibbs Sampling:   4%|▍         | 4/100 [00:17<06:07,  3.83s/iter]
# Check Theta: [0.72491561 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:   5%|▌         | 5/100 [00:21<06:02,  3.82s/iter]
# Check Theta: [0.32449744 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:   6%|▌         | 6/100 [00:24<05:54,  3.78s/iter]
# Check Theta: [0.69457494 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:   7%|▋         | 7/100 [00:28<05:47,  3.73s/iter]
# Check Theta: [0.83096356 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:   8%|▊         | 8/100 [00:31<05:23,  3.51s/iter]
# Check Theta: [0.32822577 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:   9%|▉         | 9/100 [00:34<05:08,  3.39s/iter]
# Check Theta: [0.67064513 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:  10%|█         | 10/100 [00:38<05:10,  3.45s/iter]
# Check Theta: [0.41512131 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:  11%|█         | 11/100 [00:41<05:05,  3.43s/iter]
# Check Theta: [0.5894722 0.        0.        0.        0.        0.        0.
#  0.       ]
# Gibbs Sampling:  21%|██        | 21/100 [01:12<03:59,  3.04s/iter]
# Check Theta: [0.08296695 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:  31%|███       | 31/100 [01:43<03:45,  3.27s/iter]
# Check Theta: [0.43428221 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:  41%|████      | 41/100 [02:15<03:05,  3.14s/iter]
# Check Theta: [0.71036911 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:  51%|█████     | 51/100 [02:46<02:34,  3.15s/iter]
# Check Theta: [0.64786249 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:  61%|██████    | 61/100 [03:18<02:02,  3.14s/iter]
# Check Theta: [0.74633288 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:  71%|███████   | 71/100 [03:50<01:27,  3.01s/iter]
# Check Theta: [0.3804515 0.        0.        0.        0.        0.        0.
#  0.       ]
# Gibbs Sampling:  81%|████████  | 81/100 [04:21<01:05,  3.43s/iter]
# Check Theta: [0.31634859 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling:  91%|█████████ | 91/100 [04:54<00:28,  3.14s/iter]
# Check Theta: [0.41554141 0.         0.         0.         0.         0.
#  0.         0.        ]
# Gibbs Sampling: 100%|██████████| 100/100 [05:22<00:00,  3.23s/iter]

# %%
from src.sampling.ghosh_dunson import GhoshDunsonGibbs
# Initiate Bayesian Normal Factor Gibbs Sampler
SparseGibbsSampling = GhoshDunsonGibbs(
    Y=Y_sim,
    B=BTrue,
    Sigma=SigmaTrue,
    Gamma=Gamma0,
    Theta=Theta0,
    alpha=alpha,
    eta=eta,
    epsilon=epsilon,
    lambda0=lambda0,
    lambda1=lambda1,
)

# Perform Gibbs Sampler for posterior
SparseGibbsSampling.perform_gibbs(iterations=100,tp='q')
# Out:
# Gibbs Sampling:   1%|          | 1/100 [00:03<06:20,  3.84s/iter]
# Check Theta: [0.27818323 0.27808434 0.27332658 0.27167556 0.2692715  0.00586843
#  0.00549088 0.00106462]
# Gibbs Sampling:   2%|▏         | 2/100 [00:07<05:59,  3.66s/iter]
# Check Theta: [2.80490247e-01 2.76393909e-01 2.68717287e-01 2.64263384e-01
#  2.63760727e-01 4.27860735e-03 4.20707900e-03 2.69880183e-04]
# Gibbs Sampling:   3%|▎         | 3/100 [00:10<05:30,  3.41s/iter]
# Check Theta: [0.27583953 0.2702522  0.27000968 0.26497666 0.26418988 0.00296318
#  0.00269477 0.0003128 ]
# Gibbs Sampling:   4%|▍         | 4/100 [00:13<05:18,  3.32s/iter]
# Check Theta: [2.72614583e-01 2.71872017e-01 2.67953471e-01 2.67251928e-01
#  2.62358717e-01 4.34557463e-03 2.49708288e-03 1.73304847e-04]
# Gibbs Sampling:   5%|▌         | 5/100 [00:16<05:09,  3.26s/iter]
# Check Theta: [0.27693511 0.2717218  0.27165867 0.26763533 0.26669691 0.00364347
#  0.0025783  0.00037814]
# Gibbs Sampling:   6%|▌         | 6/100 [00:20<05:12,  3.32s/iter]
# Check Theta: [0.28478053 0.27046449 0.26835696 0.26636205 0.2593514  0.00371286
#  0.00334168 0.00036266]
# Gibbs Sampling:   7%|▋         | 7/100 [00:23<05:10,  3.34s/iter]
# Check Theta: [0.28528496 0.27546115 0.26835086 0.26761376 0.25966626 0.00265313
#  0.00245353 0.00072665]
# Gibbs Sampling:   8%|▊         | 8/100 [00:26<04:59,  3.26s/iter]
# Check Theta: [0.28593254 0.27720856 0.26310887 0.26208165 0.25802384 0.0044419
#  0.00256107 0.00038363]
# Gibbs Sampling:   9%|▉         | 9/100 [00:29<04:52,  3.22s/iter]
# Check Theta: [0.28082228 0.27622465 0.27584806 0.25999164 0.25034915 0.00375419
#  0.00371734 0.00118975]
# Gibbs Sampling:  10%|█         | 10/100 [00:33<04:53,  3.27s/iter]
# Check Theta: [2.83627839e-01 2.77280853e-01 2.75631134e-01 2.58391138e-01
#  2.57999095e-01 4.18119943e-03 2.22601112e-03 1.31316554e-04]
# Gibbs Sampling:  11%|█         | 11/100 [00:36<04:53,  3.30s/iter]
# Check Theta: [0.29017432 0.27730315 0.27341125 0.25821194 0.25467899 0.0064929
#  0.00319893 0.0015362 ]
# Gibbs Sampling:  21%|██        | 21/100 [01:09<04:21,  3.31s/iter]
# Check Theta: [0.27892231 0.27113578 0.26582384 0.25978455 0.25268517 0.00490236
#  0.0041854  0.00039809]
# Gibbs Sampling:  31%|███       | 31/100 [01:40<03:40,  3.20s/iter]
# Check Theta: [2.85220246e-01 2.81354772e-01 2.80345427e-01 2.68005311e-01
#  2.57719262e-01 4.85256473e-03 2.57500967e-04 1.22084564e-04]
# Gibbs Sampling:  41%|████      | 41/100 [02:14<03:24,  3.47s/iter]
# Check Theta: [3.01100372e-01 2.92564126e-01 2.90833869e-01 2.90110157e-01
#  2.95022049e-01 9.89579927e-01 9.89659189e-01 7.67653784e-04]
# Gibbs Sampling:  51%|█████     | 51/100 [02:48<02:49,  3.46s/iter]
# Check Theta: [0.3288146  0.30691242 0.30109585 0.3010912  0.308027   0.94417345
#  0.94587294 0.00100691]
# Gibbs Sampling:  61%|██████    | 61/100 [03:23<02:19,  3.58s/iter]
# Check Theta: [0.31729729 0.31254568 0.31005655 0.30941998 0.32205204 0.9088426
#  0.91295853 0.00137092]
# Gibbs Sampling:  71%|███████   | 71/100 [03:56<01:32,  3.20s/iter]
# Check Theta: [3.32281149e-01 3.25175134e-01 3.24989270e-01 3.26032186e-01
#  3.34973149e-01 8.65691646e-01 8.65760301e-01 2.63973558e-04]
# Gibbs Sampling:  81%|████████  | 81/100 [04:28<00:59,  3.14s/iter]
# Check Theta: [3.57866541e-01 3.56877230e-01 3.52237433e-01 3.58165337e-01
#  3.67308201e-01 8.23581775e-01 8.25552653e-01 4.04401265e-04]
# Gibbs Sampling:  91%|█████████ | 91/100 [05:00<00:28,  3.11s/iter]
# Check Theta: [3.73038995e-01 3.69992078e-01 3.69938344e-01 3.69548361e-01
#  3.69939690e-01 7.85796819e-01 7.87302517e-01 3.40631243e-04]
# Gibbs Sampling: 100%|██████████| 100/100 [05:28<00:00,  3.29s/iter]

# %%
from src.sampling.normal_factor_gibbs import SpSlNormalFactorGibbs

# Initiate Bayesian Normal Factor Gibbs Sampler
SparseGibbsSampling2 = SpSlNormalFactorGibbs(
    Y=Y_sim,
    B=BTrue,
    Sigma=SigmaTrue,
    Gamma=Gamma0,
    Theta=Theta0,
    alpha=alpha,
    eta=eta,
    epsilon=epsilon,
    lambda0=lambda0,
    lambda1=lambda1,
)

# Perform Gibbs Sampler for posterior
SparseGibbsSampling2.perform_gibbs(iterations=100)
# Out:
# Gibbs Sampling:   1%|          | 1/100 [00:08<13:12,  8.00s/iter]
# Check Theta: [0.28069003 0.27902575 0.27274481 0.26237709 0.24923809 0.0076603
#  0.00744103 0.00160389]
# Gibbs Sampling:   2%|▏         | 2/100 [00:10<08:08,  4.99s/iter]
# Check Theta: [2.79146481e-01 2.77945577e-01 2.72817126e-01 2.72132712e-01
#  2.55301324e-01 2.53471578e-03 1.58108129e-03 2.40480169e-04]
# Gibbs Sampling:   3%|▎         | 3/100 [00:13<06:35,  4.07s/iter]
# Check Theta: [0.36828515 0.27804195 0.27240838 0.27194586 0.27156473 0.00196585
#  0.00145723 0.00041938]
# Gibbs Sampling:   4%|▍         | 4/100 [00:16<05:45,  3.60s/iter]
# Check Theta: [0.46686182 0.32135529 0.32091588 0.37757389 0.39180363 1.
#  1.         0.00145595]
# Gibbs Sampling:   5%|▌         | 5/100 [00:20<05:42,  3.60s/iter]
# Check Theta: [0.45994555 0.33446173 0.33188611 0.40230948 0.40259914 0.99849674
#  0.99964499 0.09739585]
# Gibbs Sampling:   6%|▌         | 6/100 [00:24<06:01,  3.85s/iter]
# Check Theta: [0.45461806 0.34994974 0.34917811 0.40199128 0.40365984 0.96791866
#  0.99488175 0.35053212]
# Gibbs Sampling:   7%|▋         | 7/100 [00:28<05:56,  3.84s/iter]
# Check Theta: [0.4535512  0.35562688 0.35185384 0.40673982 0.40713195 0.76827692
#  0.96560872 0.48099327]
# Gibbs Sampling:   8%|▊         | 8/100 [00:31<05:35,  3.64s/iter]
# Check Theta: [1.         1.         0.37942426 0.42821428 0.43034087 0.54397396
#  0.76720001 0.54328775]
# Gibbs Sampling:   9%|▉         | 9/100 [00:34<05:16,  3.48s/iter]
# Check Theta: [0.99937116 0.99857313 0.42940543 0.42809355 0.42843013 0.43423145
#  0.54380673 0.53912298]
# Gibbs Sampling:  10%|█         | 10/100 [00:38<05:05,  3.40s/iter]
# Check Theta: [0.99009099 0.96993823 0.43166509 0.4291614  0.42854721 0.42946606
#  0.53259357 0.53398206]
# Gibbs Sampling:  11%|█         | 11/100 [00:41<04:57,  3.34s/iter]
# Check Theta: [0.91214938 0.72417754 0.43501682 0.43154733 0.42961316 1.
#  0.52859833 0.52881768]
# Gibbs Sampling:  21%|██        | 21/100 [01:11<03:56,  3.00s/iter]
# Check Theta: [0.74237477 0.46424981 0.46361835 0.46387904 0.46576781 0.62362995
#  0.76239816 0.57040992]
# Gibbs Sampling:  31%|███       | 31/100 [01:40<03:27,  3.01s/iter]
# Check Theta: [0.99992748 0.99042843 0.50035717 0.49892936 0.49941182 0.69525016
#  0.78313091 0.55403912]
# Gibbs Sampling:  41%|████      | 41/100 [02:08<02:40,  2.71s/iter]
# Check Theta: [1.         1.         1.         1.         1.         0.97252823
#  0.82224991 0.55652729]
# Gibbs Sampling:  51%|█████     | 51/100 [02:35<02:10,  2.67s/iter]
# Check Theta: [1.         1.         1.         1.         1.         0.99028365
#  0.8869496  0.53078718]
# Gibbs Sampling:  61%|██████    | 61/100 [03:02<01:45,  2.70s/iter]
# Check Theta: [0.99934155 0.96461597 0.96313592 0.95470541 0.94610433 0.94600441
#  0.9452499  0.50089486]
# Gibbs Sampling:  71%|███████   | 71/100 [03:28<01:17,  2.67s/iter]
# Check Theta: [0.9998869  0.99964771 0.99962986 0.99901901 0.99358451 0.95194378
#  0.94578096 0.53182806]
# Gibbs Sampling:  81%|████████  | 81/100 [03:56<00:52,  2.76s/iter]
# Check Theta: [0.99996951 0.99966515 0.9988576  0.99635802 0.98433316 0.97912838
#  0.97070562 0.54874379]
# Gibbs Sampling:  91%|█████████ | 91/100 [04:23<00:24,  2.69s/iter]
# Check Theta: [0.99937309 0.99926274 0.99907978 0.99908905 0.99914502 0.99814348
#  0.99200852 0.55438729]
# Gibbs Sampling: 100%|██████████| 100/100 [04:47<00:00,  2.88s/iter]

# %%
from src.sampling.orthonormal_factor_gibbs import OrthonormalFactorGibbs

# Initiate Bayesian Normal Factor Gibbs Sampler
SparseGibbsSampling3 = OrthonormalFactorGibbs(
    Y=Y_sim,
    B=BTrue,
    Sigma=SigmaTrue,
    Gamma=Gamma0,
    Theta=Theta0,
    alpha=alpha,
    eta=eta,
    epsilon=epsilon,
    lambda0=lambda0,
    lambda1=lambda1,
)
# # Perform Gibbs Sampler for posterior
SparseGibbsSampling3.perform_gibbs(iterations=100)
# Out:
# Gibbs Sampling:   0%|          | 0/100 [00:00<?, ?iter/s]
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# Gibbs Sampling:   1%|          | 1/100 [00:08<13:38,  8.27s/iter]
# Check Theta: [0.27011756 0.26988112 0.26915658 0.26890168 0.26663111 0.00776454
#  0.00401179 0.00377041]
# Gibbs Sampling:   2%|▏         | 2/100 [00:11<08:52,  5.43s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# Check Theta: [0.27023375 0.26742464 0.26662312 0.26407619 0.26085151 0.00602695
#  0.00400903 0.0011834 ]
# Gibbs Sampling:   3%|▎         | 3/100 [00:14<07:03,  4.37s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# Check Theta: [0.26891195 0.26872761 0.26536253 0.2299427  0.22956085 0.00623305
#  0.0044914  0.0039406 ]
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# Gibbs Sampling:   4%|▍         | 4/100 [00:18<06:32,  4.09s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# Check Theta: [0.26948578 0.2688642  0.26155462 0.23388395 0.22483499 0.00605231
#  0.00237801 0.00229072]
# Gibbs Sampling:   5%|▌         | 5/100 [00:21<06:08,  3.87s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# Check Theta: [0.26115397 0.26106289 0.24245116 0.22848168 0.22575388 0.00614006
#  0.00223427 0.0018263 ]
# Gibbs Sampling:   6%|▌         | 6/100 [00:25<05:39,  3.62s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# Check Theta: [1.         0.26109009 0.26088013 0.23205911 0.22464421 0.00906611
#  0.0020683  0.00159645]
# Gibbs Sampling:   7%|▋         | 7/100 [00:28<05:29,  3.54s/iter]
# Check Theta: [0.99998198 0.29704452 0.25877958 0.22546411 0.22456192 0.0041888
#  0.00182575 0.00150801]
# Gibbs Sampling:   8%|▊         | 8/100 [00:32<05:33,  3.62s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# Check Theta: [0.99970346 0.31766168 0.2776944  0.22767586 0.22445444 0.00497474
#  0.00405789 0.00176634]
# Gibbs Sampling:   9%|▉         | 9/100 [00:35<05:23,  3.55s/iter]
# Check Theta: [0.999522   0.30843123 0.2818545  0.22596469 0.22408515 0.0046256
#  0.00435743 0.00404396]
# Gibbs Sampling:  10%|█         | 10/100 [00:38<05:05,  3.40s/iter]
# Check Theta: [0.9994351  0.32227704 0.27243933 0.23267687 0.22526674 0.0060394
#  0.00431885 0.00424548]
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  11%|█         | 11/100 [00:42<04:59,  3.37s/iter]
# Check Theta: [0.999286   0.30332613 0.3030423  0.23520218 0.22990829 0.00640263
#  0.00516197 0.00419794]
# Gibbs Sampling:  14%|█▍        | 14/100 [00:51<04:31,  3.15s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# /home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  15%|█▌        | 15/100 [00:54<04:24,  3.11s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:89: RuntimeWarning: overflow encountered in exp
#   ) * np.exp(np.linalg.norm(proj) * d / var**2)
# /home/ymachta/bayesian_factor/src/sampling/metropolis_hastings.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   acceptance_ratio = proposed_pdf / np.maximum(current_pdf, 1e-10)
# Gibbs Sampling:  16%|█▌        | 16/100 [00:57<04:19,  3.09s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  19%|█▉        | 19/100 [01:05<04:00,  2.97s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  21%|██        | 21/100 [01:11<03:53,  2.96s/iter]
# Check Theta: [0.99954522 0.33271208 0.32723494 0.25393613 0.25349627 0.99786665
#  0.99894283 0.01690775]
# Gibbs Sampling:  31%|███       | 31/100 [01:47<04:06,  3.57s/iter]
# Check Theta: [0.9990909  0.99802694 0.97168087 0.91324418 0.91279828 0.84781872
#  0.75436853 0.01328714]
# Gibbs Sampling:  33%|███▎      | 33/100 [01:54<03:47,  3.39s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  41%|████      | 41/100 [02:19<03:05,  3.14s/iter]
# Check Theta: [0.97976303 0.97256677 0.88769201 0.8206317  0.79429028 0.6717614
#  0.52654152 0.00668441]
# Gibbs Sampling:  46%|████▌     | 46/100 [02:36<03:08,  3.48s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  51%|█████     | 51/100 [02:53<02:50,  3.47s/iter]
# Check Theta: [0.99993572 0.99990111 0.99983268 0.99986417 0.62203841 0.5762873
#  0.30464615 0.00328698]
# Gibbs Sampling:  52%|█████▏    | 52/100 [02:57<02:47,  3.50s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  55%|█████▌    | 55/100 [03:08<02:47,  3.72s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  61%|██████    | 61/100 [03:29<02:19,  3.57s/iter]
# Check Theta: [0.99937918 0.99935817 0.99752709 0.99266557 0.47637296 0.3824222
#  0.24800512 0.00736289]
# Gibbs Sampling:  67%|██████▋   | 67/100 [03:51<02:02,  3.72s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  69%|██████▉   | 69/100 [03:59<01:56,  3.77s/iter]/home/ymachta/bayesian_factor/src/sampling/orthonormal_factor_gibbs.py:87: RuntimeWarning: overflow encountered in scalar multiply
#   return (self.num_obs - d**2) ** (
# Gibbs Sampling:  71%|███████   | 71/100 [04:07<01:50,  3.82s/iter]
# Check Theta: [0.98744291 0.98421494 0.98234974 0.97193157 0.47141155 0.28614134
#  0.19874753 0.00357088]
# Gibbs Sampling:  81%|████████  | 81/100 [04:49<01:23,  4.37s/iter]
# Check Theta: [1.         1.         1.         0.89331358 0.43537395 0.21270656
#  0.20760009 0.00572825]
# Gibbs Sampling:  91%|█████████ | 91/100 [05:31<00:36,  4.05s/iter]
# Check Theta: [0.99362198 0.99284421 0.98844057 0.81751249 0.37369153 0.15318461
#  0.14991962 0.        ]
# Gibbs Sampling: 100%|██████████| 100/100 [06:10<00:00,  3.71s/iter]
